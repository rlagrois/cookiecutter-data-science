# %%
##### USE THIS NOTEBOOK AS A BASE WHEN USING COOKIECUTTER REPOSITORY
##### MORE LIBRARIES MAY BE ADDED AS NEEDED
##### ONCE REPO IS ON LOCAL MACHINE RUN "git add --all" FOLLOWED BY "pip install --editable ."
##### IN COMMAND PROMPT (PROJECT ROOT), THEN RUN NOTEBOOK AND FUNCTIONS SHOULD PRINT
##### IF SRC DOESN'T WORK SHUT DOWN JUPYTER THEN RERUN --EDITABLE COMMAND

# %% [markdown]
# **Hide code meta data:**
# {
#    "trusted":true,
#    "tags":[
#       "hidecode"
#    ]
# }
#
# **hide code and output:**
#
# {
#    "trusted":true,
#    "tags":[
#       "removecell"
#    ]
# }

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import src.cust.func as fn
import src.data.prep as p
import src.viz.viz as viz

# %%
fn.test()
p.test()
viz.test()
print(os.listdir())

# %%
pp.available()
